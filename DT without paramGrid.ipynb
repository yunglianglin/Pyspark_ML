# %% [markdown]
# # Start a Spark Session

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('pipeline').getOrCreate()

# %% [markdown]
# # Load data from HDFS

# %%
#create dataframe by loading data with sqlContext.read()
row_df = spark.read.format("csv")\
         .option("header", "true")\
         .option("delimiter", "\t")\
         .load("hdfs://mycluster/user/dtree/data/train.tsv")
print(row_df.count())
# Out:
# 7395

# %%
type(row_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
row_df.printSchema()
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- urlid: string (nullable = true)
#  |-- boilerplate: string (nullable = true)
#  |-- alchemy_category: string (nullable = true)
#  |-- alchemy_category_score: string (nullable = true)
#  |-- avglinksize: string (nullable = true)
#  |-- commonlinkratio_1: string (nullable = true)
#  |-- commonlinkratio_2: string (nullable = true)
#  |-- commonlinkratio_3: string (nullable = true)
#  |-- commonlinkratio_4: string (nullable = true)
#  |-- compression_ratio: string (nullable = true)
#  |-- embed_ratio: string (nullable = true)
#  |-- framebased: string (nullable = true)
#  |-- frameTagRatio: string (nullable = true)
#  |-- hasDomainLink: string (nullable = true)
#  |-- html_ratio: string (nullable = true)
#  |-- image_ratio: string (nullable = true)
#  |-- is_news: string (nullable = true)
#  |-- lengthyLinkDomain: string (nullable = true)
#  |-- linkwordscore: string (nullable = true)
#  |-- news_front_page: string (nullable = true)
#  |-- non_markup_alphanum_characters: string (nullable = true)
#  |-- numberOfLinks: string (nullable = true)
#  |-- numwords_in_url: string (nullable = true)
#  |-- parametrizedLinkRatio: string (nullable = true)
#  |-- spelling_errors_ratio: string (nullable = true)
#  |-- label: string (nullable = true)

# %%
row_df.select('url', 'alchemy_category', 'alchemy_category_score', 'is_news', 'label').show(10)
# Out:
# +--------------------+------------------+----------------------+-------+-----+
# |                 url|  alchemy_category|alchemy_category_score|is_news|label|
# +--------------------+------------------+----------------------+-------+-----+
# |http://www.bloomb...|          business|              0.789131|      1|    0|
# |http://www.popsci...|        recreation|              0.574147|      1|    1|
# |http://www.menshe...|            health|              0.996526|      1|    1|
# |http://www.dumbli...|            health|              0.801248|      1|    1|
# |http://bleacherre...|            sports|              0.719157|      1|    0|
# |http://www.conven...|                 ?|                     ?|      ?|    0|
# |http://gofashionl...|arts_entertainment|               0.22111|      1|    1|
# |http://www.inside...|                 ?|                     ?|      ?|    0|
# |http://www.valetm...|                 ?|                     ?|      1|    1|
# |http://www.howswe...|                 ?|                     ?|      ?|    1|
# +--------------------+------------------+----------------------+-------+-----+
# only showing top 10 rows

# %%
#set up UDF Function
from pyspark.sql.functions import udf

def replace_question(x):
    return ("0" if x=="?" else x)

#transform replace_question into DataFrames UDF 
replace_question=udf(replace_question)

# %%
# returns a column based on the given column name
from pyspark.sql.functions import col 

df = row_df.select(
    ['url', 'alchemy_category']+  #select columns without further transformation
    [replace_question(col(column)).cast("double").alias(column) 
    for column in row_df.columns[4:]])
     #transform the type of column from string to double 
     #perform UDF on columns starting from the forth

# %%
df.select('url', 'alchemy_category', 'alchemy_category_score', 'is_news', 'label').show(10)
# Out:
# +--------------------+------------------+----------------------+-------+-----+
# |                 url|  alchemy_category|alchemy_category_score|is_news|label|
# +--------------------+------------------+----------------------+-------+-----+
# |http://www.bloomb...|          business|              0.789131|    1.0|  0.0|
# |http://www.popsci...|        recreation|              0.574147|    1.0|  1.0|
# |http://www.menshe...|            health|              0.996526|    1.0|  1.0|
# |http://www.dumbli...|            health|              0.801248|    1.0|  1.0|
# |http://bleacherre...|            sports|              0.719157|    1.0|  0.0|
# |http://www.conven...|                 ?|                   0.0|    0.0|  0.0|
# |http://gofashionl...|arts_entertainment|               0.22111|    1.0|  1.0|
# |http://www.inside...|                 ?|                   0.0|    0.0|  0.0|
# |http://www.valetm...|                 ?|                   0.0|    1.0|  1.0|
# |http://www.howswe...|                 ?|                   0.0|    0.0|  1.0|
# +--------------------+------------------+----------------------+-------+-----+
# only showing top 10 rows

# %%
print (df.printSchema())
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- alchemy_category: string (nullable = true)
#  |-- alchemy_category_score: double (nullable = true)
#  |-- avglinksize: double (nullable = true)
#  |-- commonlinkratio_1: double (nullable = true)
#  |-- commonlinkratio_2: double (nullable = true)
#  |-- commonlinkratio_3: double (nullable = true)
#  |-- commonlinkratio_4: double (nullable = true)
#  |-- compression_ratio: double (nullable = true)
#  |-- embed_ratio: double (nullable = true)
#  |-- framebased: double (nullable = true)
#  |-- frameTagRatio: double (nullable = true)
#  |-- hasDomainLink: double (nullable = true)
#  |-- html_ratio: double (nullable = true)
#  |-- image_ratio: double (nullable = true)
#  |-- is_news: double (nullable = true)
#  |-- lengthyLinkDomain: double (nullable = true)
#  |-- linkwordscore: double (nullable = true)
#  |-- news_front_page: double (nullable = true)
#  |-- non_markup_alphanum_characters: double (nullable = true)
#  |-- numberOfLinks: double (nullable = true)
#  |-- numwords_in_url: double (nullable = true)
#  |-- parametrizedLinkRatio: double (nullable = true)
#  |-- spelling_errors_ratio: double (nullable = true)
#  |-- label: double (nullable = true)
#
# None

# %% [markdown]
# # Split data into training set & test set

# %%
train_df, test_df = df.randomSplit([0.7, 0.3])

# %%
train_df.count(), test_df.count()
# Out:
# (5152, 2243)

# %%
train_df.take(1)
# Out:
# [Row(url='http://1000awesomethings.com/2008/12/29/864-mastering-the-art-of-the-all-you-can-eat-buffet/', alchemy_category='arts_entertainment', alchemy_category_score=0.5811, avglinksize=2.526785714, commonlinkratio_1=0.680672269, commonlinkratio_2=0.327731092, commonlinkratio_3=0.268907563, commonlinkratio_4=0.260504202, compression_ratio=0.471047228, embed_ratio=0.0, framebased=0.0, frameTagRatio=0.027673897, hasDomainLink=0.0, html_ratio=0.218407242, image_ratio=0.105263158, is_news=1.0, lengthyLinkDomain=1.0, linkwordscore=13.0, news_front_page=0.0, non_markup_alphanum_characters=16382.0, numberOfLinks=238.0, numwords_in_url=8.0, parametrizedLinkRatio=0.336134454, spelling_errors_ratio=0.094298246, label=1.0)]

# %% [markdown]
# # Prepare data #1 - StringIndexer

# %%
from pyspark.ml.feature import StringIndexer
categoryIndexer = StringIndexer(
                    inputCol='alchemy_category',
                    outputCol='alchemy_category_Index')

# %%
categoryTransformer=categoryIndexer.fit(df)

# %%
type(categoryTransformer)
# Out:
# pyspark.ml.feature.StringIndexerModel

# %%
df_1=categoryTransformer.transform(train_df)

# %%
#index category of each record
df_1.select("alchemy_category", "alchemy_category_Index").show(15)
# Out:
# +------------------+----------------------+
# |  alchemy_category|alchemy_category_Index|
# +------------------+----------------------+
# |arts_entertainment|                   2.0|
# |                 ?|                   0.0|
# |                 ?|                   0.0|
# |          business|                   3.0|
# |arts_entertainment|                   2.0|
# |                 ?|                   0.0|
# |                 ?|                   0.0|
# |                 ?|                   0.0|
# |                 ?|                   0.0|
# |        recreation|                   1.0|
# | computer_internet|                   7.0|
# |          business|                   3.0|
# |arts_entertainment|                   2.0|
# |            sports|                   5.0|
# |                 ?|                   0.0|
# +------------------+----------------------+
# only showing top 15 rows

# %% [markdown]
# # Prepare data #2 - OneHotEncoder

# %%
from pyspark.ml.feature import OneHotEncoderEstimator
encoder = OneHotEncoderEstimator(dropLast=False,
                       inputCols=["alchemy_category_Index"],
                       outputCols=["alchemy_category_IndexVec"])

# %%
#Fits a model to the input dataset with optional parameters.
df_2 = encoder.fit(df_1)

# %%
#Transforms the input dataset with optional parameters.
df_2 = df_2.transform(df_1)

# %%
df_2.select("alchemy_category", "alchemy_category_Index", "alchemy_category_IndexVec").show(15)
# Out:
# +------------------+----------------------+-------------------------+
# |  alchemy_category|alchemy_category_Index|alchemy_category_IndexVec|
# +------------------+----------------------+-------------------------+
# |arts_entertainment|                   2.0|           (14,[2],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |          business|                   3.0|           (14,[3],[1.0])|
# |arts_entertainment|                   2.0|           (14,[2],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# |        recreation|                   1.0|           (14,[1],[1.0])|
# | computer_internet|                   7.0|           (14,[7],[1.0])|
# |          business|                   3.0|           (14,[3],[1.0])|
# |arts_entertainment|                   2.0|           (14,[2],[1.0])|
# |            sports|                   5.0|           (14,[5],[1.0])|
# |                 ?|                   0.0|           (14,[0],[1.0])|
# +------------------+----------------------+-------------------------+
# only showing top 15 rows

# %% [markdown]
# # Prepare data#3 - VectorAssembler

# %%
from pyspark.ml.feature import VectorAssembler
#select all columns without "label" and the first three columns
assemblerInputs=['alchemy_category_IndexVec']+row_df.columns[4:-1]
print(assemblerInputs)
# Out:
# ['alchemy_category_IndexVec', 'alchemy_category_score', 'avglinksize', 'commonlinkratio_1', 'commonlinkratio_2', 'commonlinkratio_3', 'commonlinkratio_4', 'compression_ratio', 'embed_ratio', 'framebased', 'frameTagRatio', 'hasDomainLink', 'html_ratio', 'image_ratio', 'is_news', 'lengthyLinkDomain', 'linkwordscore', 'news_front_page', 'non_markup_alphanum_characters', 'numberOfLinks', 'numwords_in_url', 'parametrizedLinkRatio', 'spelling_errors_ratio']

# %%
#VectorAssembler is a transformer that combines a given list of columns into a single vector column. 
assembler = VectorAssembler(
            inputCols=assemblerInputs,
            outputCol="features")

# %%
df_3 = assembler.transform(df_2)

# %%
print(df_3.columns)
# Out:
# ['url', 'alchemy_category', 'alchemy_category_score', 'avglinksize', 'commonlinkratio_1', 'commonlinkratio_2', 'commonlinkratio_3', 'commonlinkratio_4', 'compression_ratio', 'embed_ratio', 'framebased', 'frameTagRatio', 'hasDomainLink', 'html_ratio', 'image_ratio', 'is_news', 'lengthyLinkDomain', 'linkwordscore', 'news_front_page', 'non_markup_alphanum_characters', 'numberOfLinks', 'numwords_in_url', 'parametrizedLinkRatio', 'spelling_errors_ratio', 'label', 'alchemy_category_Index', 'alchemy_category_IndexVec', 'features']

# %%
df_3.select('features').show(2)
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |(36,[2,14,15,16,1...|
# |(36,[0,15,16,20,2...|
# +--------------------+
# only showing top 2 rows

# %%
df_3.select('features').take(1)
# Out:
# [Row(features=SparseVector(36, {2: 1.0, 14: 0.5811, 15: 2.5268, 16: 0.6807, 17: 0.3277, 18: 0.2689, 19: 0.2605, 20: 0.471, 23: 0.0277, 25: 0.2184, 26: 0.1053, 27: 1.0, 28: 1.0, 29: 13.0, 31: 16382.0, 32: 238.0, 33: 8.0, 34: 0.3361, 35: 0.0943}))]

# %% [markdown]
# # Build a decision tree model

# %%
from pyspark.ml.classification import DecisionTreeClassifier
dt = DecisionTreeClassifier(labelCol="label", featuresCol="features",
                           impurity="gini", maxDepth=10, maxBins=14)

# %%
dt_model = dt.fit(df_3)

# %%
print(dt_model)
# Out:
# DecisionTreeClassificationModel (uid=DecisionTreeClassifier_4abe8d5a650c6501b3fc) of depth 10 with 721 nodes

# %%
df_4 = dt_model.transform(df_3)

# %%
df_3.count()
# Out:
# 5152

# %% [markdown]
# # Build ML pipeline

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoderEstimator, VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier

StringIndexer = StringIndexer(
                    inputCol='alchemy_category',
                    outputCol='alchemy_category_Index')

encoder = OneHotEncoderEstimator(dropLast=False,
                       inputCols=["alchemy_category_Index"],
                       outputCols=["alchemy_category_IndexVec"])

assemblerInputs=['alchemy_category_IndexVec']+row_df.columns[4:-1]
assembler = VectorAssembler(
            inputCols=assemblerInputs,
            outputCol="features")

dt = DecisionTreeClassifier(labelCol="label", featuresCol="features",
                           impurity="gini", maxDepth=10, maxBins=14)

dt_pipeline = Pipeline(stages=[StringIndexer,encoder,assembler, dt])

# %%
dt_pipeline.getStages()
# Out:
# [StringIndexer_47929903b50f674f8a35,
#  OneHotEncoderEstimator_4982a7da1890f6f173bc,
#  VectorAssembler_485e86381d632fdb53b4,
#  DecisionTreeClassifier_4ecb8eeab1eff1752f8e]

# %%
pipelineModel=dt_pipeline.fit(train_df)

# %%
print(pipelineModel.stages[3].toDebugString)
# Out:
# DecisionTreeClassificationModel (uid=DecisionTreeClassifier_4ecb8eeab1eff1752f8e) of depth 10 with 721 nodes
#   If (feature 31 <= 1798.0)
#    If (feature 2 in {1.0})
#     If (feature 26 <= 0.20197163950000002)
#      If (feature 25 <= 0.166685731)
#       Predict: 1.0
#      Else (feature 25 > 0.166685731)
#       If (feature 20 <= 0.485028182)
#        If (feature 16 <= 0.36377084449999997)
#         If (feature 14 <= 0.3662915)
#          Predict: 1.0
#         Else (feature 14 > 0.3662915)
#          If (feature 33 <= 7.5)
#           Predict: 0.0
#          Else (feature 33 > 7.5)
#           Predict: 1.0
#        Else (feature 16 > 0.36377084449999997)
#         If (feature 16 <= 0.5582905465)
#          Predict: 1.0
#         Else (feature 16 > 0.5582905465)
#          If (feature 14 <= 0.7377425)
#           Predict: 0.0
#          Else (feature 14 > 0.7377425)
#           Predict: 1.0
#       Else (feature 20 > 0.485028182)
#        If (feature 35 <= 0.078101539)
#         If (feature 31 <= 1315.5)
#          If (feature 29 <= 65.5)
#           If (feature 35 <= 0.040518047)
#            If (feature 15 <= 1.8312261995)
#             Predict: 1.0
#            Else (feature 15 > 1.8312261995)
#             Predict: 0.0
#           Else (feature 35 > 0.040518047)
#            Predict: 0.0
#          Else (feature 29 > 65.5)
#           If (feature 14 <= 0.23645850000000002)
#            Predict: 0.0
#           Else (feature 14 > 0.23645850000000002)
#            Predict: 1.0
#         Else (feature 31 > 1315.5)
#          If (feature 18 <= 0.0414985725)
#           Predict: 0.0
#          Else (feature 18 > 0.0414985725)
#           Predict: 1.0
#        Else (feature 35 > 0.078101539)
#         If (feature 35 <= 0.11686205399999999)
#          Predict: 0.0
#         Else (feature 35 > 0.11686205399999999)
#          If (feature 25 <= 0.2478796935)
#           Predict: 0.0
#          Else (feature 25 > 0.2478796935)
#           If (feature 25 <= 0.30454012649999995)
#            If (feature 14 <= 0.46934750000000003)
#             Predict: 0.0
#            Else (feature 14 > 0.46934750000000003)
#             Predict: 1.0
#           Else (feature 25 > 0.30454012649999995)
#            Predict: 0.0
#     Else (feature 26 > 0.20197163950000002)
#      If (feature 16 <= 0.6922237149999999)
#       If (feature 25 <= 0.2659816935)
#        If (feature 14 <= 0.23645850000000002)
#         If (feature 29 <= 33.5)
#          Predict: 1.0
#         Else (feature 29 > 33.5)
#          If (feature 35 <= 0.08356947349999999)
#           Predict: 0.0
#          Else (feature 35 > 0.08356947349999999)
#           Predict: 1.0
#        Else (feature 14 > 0.23645850000000002)
#         If (feature 34 <= 0.0028320775)
#          If (feature 25 <= 0.222973184)
#           Predict: 0.0
#          Else (feature 25 > 0.222973184)
#           Predict: 1.0
#         Else (feature 34 > 0.0028320775)
#          If (feature 35 <= 0.10804443799999999)
#           Predict: 0.0
#          Else (feature 35 > 0.10804443799999999)
#           If (feature 35 <= 0.11686205399999999)
#            If (feature 29 <= 54.5)
#             Predict: 0.0
#            Else (feature 29 > 54.5)
#             Predict: 1.0
#           Else (feature 35 > 0.11686205399999999)
#            If (feature 29 <= 6.5)
#             Predict: 1.0
#            Else (feature 29 > 6.5)
#             Predict: 0.0
#       Else (feature 25 > 0.2659816935)
#        If (feature 34 <= 0.143095238)
#         If (feature 33 <= 0.5)
#          Predict: 0.0
#         Else (feature 33 > 0.5)
#          If (feature 25 <= 0.27862231400000004)
#           If (feature 18 <= 4.04E-4)
#            If (feature 35 <= 0.040518047)
#             Predict: 0.0
#            Else (feature 35 > 0.040518047)
#             Predict: 1.0
#           Else (feature 18 > 4.04E-4)
#            Predict: 0.0
#          Else (feature 25 > 0.27862231400000004)
#           Predict: 1.0
#        Else (feature 34 > 0.143095238)
#         Predict: 0.0
#      Else (feature 16 > 0.6922237149999999)
#       Predict: 1.0
#    Else (feature 2 not in {1.0})
#     If (feature 23 <= 0.0788028065)
#      If (feature 18 <= 0.0698299575)
#       If (feature 34 <= 0.0332329315)
#        If (feature 29 <= 33.5)
#         If (feature 32 <= 51.5)
#          If (feature 23 <= 0.0455830775)
#           If (feature 33 <= 0.5)
#            If (feature 16 <= 0.239601351)
#             Predict: 1.0
#            Else (feature 16 > 0.239601351)
#             Predict: 0.0
#           Else (feature 33 > 0.5)
#            If (feature 31 <= 345.5)
#             Predict: 0.0
#            Else (feature 31 > 345.5)
#             Predict: 1.0
#          Else (feature 23 > 0.0455830775)
#           If (feature 3 in {0.0})
#            Predict: 0.0
#           Else (feature 3 not in {0.0})
#            Predict: 1.0
#         Else (feature 32 > 51.5)
#          If (feature 30 <= 0.5)
#           If (feature 3 in {1.0})
#            If (feature 14 <= 0.46934750000000003)
#             Predict: 1.0
#            Else (feature 14 > 0.46934750000000003)
#             Predict: 0.0
#           Else (feature 3 not in {1.0})
#            Predict: 1.0
#          Else (feature 30 > 0.5)
#           Predict: 0.0
#        Else (feature 29 > 33.5)
#         If (feature 15 <= 1.8312261995)
#          If (feature 28 <= 0.5)
#           If (feature 25 <= 0.2478796935)
#            If (feature 26 <= 0.91704893)
#             Predict: 0.0
#            Else (feature 26 > 0.91704893)
#             Predict: 0.0
#           Else (feature 25 > 0.2478796935)
#            If (feature 16 <= 0.312213303)
#             Predict: 0.0
#            Else (feature 16 > 0.312213303)
#             Predict: 1.0
#          Else (feature 28 > 0.5)
#           If (feature 20 <= 16.0)
#            Predict: 1.0
#           Else (feature 20 > 16.0)
#            If (feature 15 <= 1.3070798044999998)
#             Predict: 0.0
#            Else (feature 15 > 1.3070798044999998)
#             Predict: 1.0
#         Else (feature 15 > 1.8312261995)
#          If (feature 23 <= 0.030499808)
#           If (feature 16 <= 0.44433942449999997)
#            Predict: 0.0
#           Else (feature 16 > 0.44433942449999997)
#            Predict: 1.0
#          Else (feature 23 > 0.030499808)
#           If (feature 23 <= 0.0594695065)
#            Predict: 0.0
#           Else (feature 23 > 0.0594695065)
#            If (feature 4 in {1.0})
#             Predict: 1.0
#            Else (feature 4 not in {1.0})
#             Predict: 0.0
#       Else (feature 34 > 0.0332329315)
#        If (feature 25 <= 0.30454012649999995)
#         If (feature 29 <= 65.5)
#          If (feature 4 in {1.0})
#           If (feature 23 <= 0.0455830775)
#            Predict: 0.0
#           Else (feature 23 > 0.0455830775)
#            If (feature 32 <= 90.5)
#             Predict: 0.0
#            Else (feature 32 > 90.5)
#             Predict: 1.0
#          Else (feature 4 not in {1.0})
#           If (feature 33 <= 8.5)
#            If (feature 14 <= 0.6075189999999999)
#             Predict: 0.0
#            Else (feature 14 > 0.6075189999999999)
#             Predict: 0.0
#           Else (feature 33 > 8.5)
#            If (feature 31 <= 345.5)
#             Predict: 1.0
#            Else (feature 31 > 345.5)
#             Predict: 0.0
#         Else (feature 29 > 65.5)
#          If (feature 14 <= 0.807463)
#           If (feature 23 <= 0.0594695065)
#            If (feature 23 <= 0.015001365999999999)
#             Predict: 0.0
#            Else (feature 23 > 0.015001365999999999)
#             Predict: 0.0
#           Else (feature 23 > 0.0594695065)
#            If (feature 9 in {1.0})
#             Predict: 1.0
#            Else (feature 9 not in {1.0})
#             Predict: 0.0
#          Else (feature 14 > 0.807463)
#           If (feature 15 <= 1.517361948)
#            Predict: 0.0
#           Else (feature 15 > 1.517361948)
#            Predict: 1.0
#        Else (feature 25 > 0.30454012649999995)
#         If (feature 20 <= 0.6113894185)
#          If (feature 29 <= 25.5)
#           Predict: 1.0
#          Else (feature 29 > 25.5)
#           If (feature 14 <= 0.5427310000000001)
#            If (feature 3 in {1.0})
#             Predict: 0.0
#            Else (feature 3 not in {1.0})
#             Predict: 1.0
#           Else (feature 14 > 0.5427310000000001)
#            Predict: 0.0
#         Else (feature 20 > 0.6113894185)
#          If (feature 23 <= 0.0686025515)
#           If (feature 33 <= 4.5)
#            Predict: 0.0
#           Else (feature 33 > 4.5)
#            Predict: 1.0
#          Else (feature 23 > 0.0686025515)
#           Predict: 1.0
#      Else (feature 18 > 0.0698299575)
#       If (feature 1 in {1.0})
#        If (feature 23 <= 0.040342762)
#         If (feature 20 <= 0.760794702)
#          If (feature 25 <= 0.2567133755)
#           Predict: 1.0
#          Else (feature 25 > 0.2567133755)
#           If (feature 19 <= 0.016359987)
#            Predict: 1.0
#           Else (feature 19 > 0.016359987)
#            Predict: 0.0
#         Else (feature 20 > 0.760794702)
#          If (feature 28 <= 0.5)
#           Predict: 1.0
#          Else (feature 28 > 0.5)
#           If (feature 14 <= 0.5427310000000001)
#            Predict: 0.0
#           Else (feature 14 > 0.5427310000000001)
#            Predict: 1.0
#        Else (feature 23 > 0.040342762)
#         If (feature 19 <= 0.0582267425)
#          If (feature 32 <= 203.5)
#           Predict: 1.0
#          Else (feature 32 > 203.5)
#           Predict: 0.0
#         Else (feature 19 > 0.0582267425)
#          Predict: 0.0
#       Else (feature 1 not in {1.0})
#        If (feature 34 <= 0.143095238)
#         If (feature 20 <= 0.394104536)
#          If (feature 21 <= 9.0E-5)
#           Predict: 1.0
#          Else (feature 21 > 9.0E-5)
#           Predict: 0.0
#         Else (feature 20 > 0.394104536)
#          If (feature 34 <= 0.114543575)
#           If (feature 29 <= 39.5)
#            If (feature 32 <= 72.5)
#             Predict: 1.0
#            Else (feature 32 > 72.5)
#             Predict: 0.0
#           Else (feature 29 > 39.5)
#            If (feature 5 in {1.0})
#             Predict: 0.0
#            Else (feature 5 not in {1.0})
#             Predict: 0.0
#          Else (feature 34 > 0.114543575)
#           If (feature 16 <= 0.409422396)
#            Predict: 0.0
#           Else (feature 16 > 0.409422396)
#            If (feature 35 <= 0.040518047)
#             Predict: 0.0
#            Else (feature 35 > 0.040518047)
#             Predict: 1.0
#        Else (feature 34 > 0.143095238)
#         If (feature 14 <= 0.7377425)
#          If (feature 25 <= 0.2394888225)
#           If (feature 6 in {1.0})
#            Predict: 1.0
#           Else (feature 6 not in {1.0})
#            If (feature 11 in {1.0})
#             Predict: 1.0
#            Else (feature 11 not in {1.0})
#             Predict: 0.0
#          Else (feature 25 > 0.2394888225)
#           If (feature 35 <= 0.0952147295)
#            Predict: 1.0
#           Else (feature 35 > 0.0952147295)
#            If (feature 32 <= 90.5)
#             Predict: 1.0
#            Else (feature 32 > 90.5)
#             Predict: 0.0
#         Else (feature 14 > 0.7377425)
#          If (feature 16 <= 0.7626690635)
#           Predict: 0.0
#          Else (feature 16 > 0.7626690635)
#           Predict: 1.0
#     Else (feature 23 > 0.0788028065)
#      If (feature 29 <= 46.5)
#       If (feature 29 <= 9.5)
#        If (feature 16 <= 0.312213303)
#         If (feature 35 <= 0.040518047)
#          If (feature 0 in {0.0})
#           Predict: 0.0
#          Else (feature 0 not in {0.0})
#           Predict: 1.0
#         Else (feature 35 > 0.040518047)
#          If (feature 1 in {0.0})
#           Predict: 0.0
#          Else (feature 1 not in {0.0})
#           If (feature 20 <= 0.6113894185)
#            Predict: 0.0
#           Else (feature 20 > 0.6113894185)
#            Predict: 1.0
#        Else (feature 16 > 0.312213303)
#         If (feature 3 in {1.0})
#          Predict: 0.0
#         Else (feature 3 not in {1.0})
#          Predict: 1.0
#       Else (feature 29 > 9.5)
#        If (feature 20 <= 0.4993590195)
#         If (feature 19 <= 4.04E-4)
#          If (feature 23 <= 0.121407927)
#           If (feature 34 <= 0.0891973125)
#            Predict: 0.0
#           Else (feature 34 > 0.0891973125)
#            If (feature 15 <= 1.517361948)
#             Predict: 1.0
#            Else (feature 15 > 1.517361948)
#             Predict: 0.0
#          Else (feature 23 > 0.121407927)
#           If (feature 14 <= 0.5427310000000001)
#            If (feature 17 <= 0.002472188)
#             Predict: 0.0
#            Else (feature 17 > 0.002472188)
#             Predict: 1.0
#           Else (feature 14 > 0.5427310000000001)
#            If (feature 14 <= 0.7377425)
#             Predict: 0.0
#            Else (feature 14 > 0.7377425)
#             Predict: 1.0
#         Else (feature 19 > 4.04E-4)
#          If (feature 28 <= 0.5)
#           Predict: 1.0
#          Else (feature 28 > 0.5)
#           If (feature 16 <= 0.36377084449999997)
#            Predict: 0.0
#           Else (feature 16 > 0.36377084449999997)
#            If (feature 25 <= 0.23083599049999998)
#             Predict: 0.0
#            Else (feature 25 > 0.23083599049999998)
#             Predict: 1.0
#        Else (feature 20 > 0.4993590195)
#         If (feature 25 <= 0.2659816935)
#          If (feature 16 <= 0.5582905465)
#           If (feature 7 in {1.0})
#            If (feature 35 <= 0.100774562)
#             Predict: 1.0
#            Else (feature 35 > 0.100774562)
#             Predict: 0.0
#           Else (feature 7 not in {1.0})
#            If (feature 25 <= 0.18307157200000002)
#             Predict: 1.0
#            Else (feature 25 > 0.18307157200000002)
#             Predict: 0.0
#          Else (feature 16 > 0.5582905465)
#           If (feature 15 <= 1.8312261995)
#            If (feature 17 <= 0.08869223200000001)
#             Predict: 1.0
#            Else (feature 17 > 0.08869223200000001)
#             Predict: 0.0
#           Else (feature 15 > 1.8312261995)
#            Predict: 1.0
#         Else (feature 25 > 0.2659816935)
#          If (feature 26 <= 0.110140926)
#           If (feature 18 <= 0.1472803465)
#            If (feature 21 <= 9.0E-5)
#             Predict: 1.0
#            Else (feature 21 > 9.0E-5)
#             Predict: 0.0
#           Else (feature 18 > 0.1472803465)
#            Predict: 0.0
#          Else (feature 26 > 0.110140926)
#           If (feature 15 <= 1.670659971)
#            If (feature 20 <= 0.760794702)
#             Predict: 0.0
#            Else (feature 20 > 0.760794702)
#             Predict: 1.0
#           Else (feature 15 > 1.670659971)
#            If (feature 3 in {0.0})
#             Predict: 0.0
#            Else (feature 3 not in {0.0})
#             Predict: 1.0
#      Else (feature 29 > 46.5)
#       If (feature 19 <= 0.0320684215)
#        If (feature 16 <= 0.641086983)
#         If (feature 29 <= 65.5)
#          If (feature 18 <= 0.0552377215)
#           If (feature 33 <= 1.5)
#            If (feature 20 <= 16.0)
#             Predict: 1.0
#            Else (feature 20 > 16.0)
#             Predict: 0.0
#           Else (feature 33 > 1.5)
#            If (feature 34 <= 0.0028320775)
#             Predict: 0.0
#            Else (feature 34 > 0.0028320775)
#             Predict: 0.0
#          Else (feature 18 > 0.0552377215)
#           If (feature 33 <= 7.5)
#            If (feature 35 <= 0.167132216)
#             Predict: 0.0
#            Else (feature 35 > 0.167132216)
#             Predict: 1.0
#           Else (feature 33 > 7.5)
#            Predict: 1.0
#         Else (feature 29 > 65.5)
#          If (feature 26 <= 0.032277358000000006)
#           If (feature 16 <= 0.239601351)
#            If (feature 15 <= 2.75869631)
#             Predict: 1.0
#            Else (feature 15 > 2.75869631)
#             Predict: 1.0
#           Else (feature 16 > 0.239601351)
#            If (feature 11 in {0.0})
#             Predict: 0.0
#            Else (feature 11 not in {0.0})
#             Predict: 1.0
#          Else (feature 26 > 0.032277358000000006)
#           If (feature 18 <= 0.0552377215)
#            If (feature 35 <= 0.0647270415)
#             Predict: 0.0
#            Else (feature 35 > 0.0647270415)
#             Predict: 0.0
#           Else (feature 18 > 0.0552377215)
#            If (feature 15 <= 3.0912878790000002)
#             Predict: 1.0
#            Else (feature 15 > 3.0912878790000002)
#             Predict: 0.0
#        Else (feature 16 > 0.641086983)
#         If (feature 35 <= 0.100774562)
#          Predict: 1.0
#         Else (feature 35 > 0.100774562)
#          Predict: 0.0
#       Else (feature 19 > 0.0320684215)
#        If (feature 32 <= 154.5)
#         If (feature 17 <= 0.119859155)
#          If (feature 25 <= 0.27862231400000004)
#           Predict: 0.0
#          Else (feature 25 > 0.27862231400000004)
#           If (feature 17 <= 0.08869223200000001)
#            If (feature 15 <= 1.8312261995)
#             Predict: 1.0
#            Else (feature 15 > 1.8312261995)
#             Predict: 0.0
#           Else (feature 17 > 0.08869223200000001)
#            Predict: 1.0
#         Else (feature 17 > 0.119859155)
#          If (feature 5 in {0.0})
#           Predict: 0.0
#          Else (feature 5 not in {0.0})
#           If (feature 16 <= 0.409422396)
#            Predict: 1.0
#           Else (feature 16 > 0.409422396)
#            Predict: 0.0
#        Else (feature 32 > 154.5)
#         If (feature 34 <= 0.0183501685)
#          Predict: 1.0
#         Else (feature 34 > 0.0183501685)
#          Predict: 0.0
#   Else (feature 31 > 1798.0)
#    If (feature 1 in {1.0})
#     If (feature 35 <= 0.10804443799999999)
#      If (feature 23 <= 0.0947221815)
#       If (feature 26 <= 0.0099005965)
#        If (feature 20 <= 0.42028575700000004)
#         Predict: 1.0
#        Else (feature 20 > 0.42028575700000004)
#         If (feature 16 <= 0.641086983)
#          If (feature 15 <= 3.8598100229999996)
#           If (feature 21 <= 9.0E-5)
#            Predict: 0.0
#           Else (feature 21 > 9.0E-5)
#            If (feature 14 <= 0.3662915)
#             Predict: 0.0
#            Else (feature 14 > 0.3662915)
#             Predict: 1.0
#          Else (feature 15 > 3.8598100229999996)
#           Predict: 1.0
#         Else (feature 16 > 0.641086983)
#          Predict: 1.0
#       Else (feature 26 > 0.0099005965)
#        If (feature 15 <= 2.75869631)
#         If (feature 14 <= 0.07670455)
#          Predict: 0.0
#         Else (feature 14 > 0.07670455)
#          If (feature 34 <= 0.114543575)
#           If (feature 29 <= 12.5)
#            If (feature 26 <= 0.466384181)
#             Predict: 1.0
#            Else (feature 26 > 0.466384181)
#             Predict: 0.0
#           Else (feature 29 > 12.5)
#            If (feature 16 <= 0.409422396)
#             Predict: 1.0
#            Else (feature 16 > 0.409422396)
#             Predict: 1.0
#          Else (feature 34 > 0.114543575)
#           If (feature 18 <= 0.0283353405)
#            If (feature 19 <= 0.016359987)
#             Predict: 1.0
#            Else (feature 19 > 0.016359987)
#             Predict: 0.0
#           Else (feature 18 > 0.0283353405)
#            If (feature 25 <= 0.18307157200000002)
#             Predict: 1.0
#            Else (feature 25 > 0.18307157200000002)
#             Predict: 1.0
#        Else (feature 15 > 2.75869631)
#         If (feature 23 <= 0.0455830775)
#          If (feature 29 <= 46.5)
#           If (feature 33 <= 7.5)
#            Predict: 1.0
#           Else (feature 33 > 7.5)
#            If (feature 14 <= 0.5427310000000001)
#             Predict: 0.0
#            Else (feature 14 > 0.5427310000000001)
#             Predict: 1.0
#          Else (feature 29 > 46.5)
#           If (feature 15 <= 3.0912878790000002)
#            Predict: 1.0
#           Else (feature 15 > 3.0912878790000002)
#            Predict: 0.0
#         Else (feature 23 > 0.0455830775)
#          If (feature 14 <= 0.672237)
#           If (feature 16 <= 0.5582905465)
#            If (feature 14 <= 0.5427310000000001)
#             Predict: 0.0
#            Else (feature 14 > 0.5427310000000001)
#             Predict: 1.0
#           Else (feature 16 > 0.5582905465)
#            Predict: 1.0
#          Else (feature 14 > 0.672237)
#           If (feature 34 <= 0.2746007815)
#            If (feature 20 <= 0.6113894185)
#             Predict: 0.0
#            Else (feature 20 > 0.6113894185)
#             Predict: 1.0
#           Else (feature 34 > 0.2746007815)
#            Predict: 1.0
#      Else (feature 23 > 0.0947221815)
#       If (feature 26 <= 0.0626088645)
#        If (feature 27 <= 0.5)
#         If (feature 14 <= 0.3662915)
#          Predict: 1.0
#         Else (feature 14 > 0.3662915)
#          Predict: 0.0
#        Else (feature 27 > 0.5)
#         If (feature 14 <= 0.46934750000000003)
#          If (feature 15 <= 1.3070798044999998)
#           Predict: 1.0
#          Else (feature 15 > 1.3070798044999998)
#           Predict: 0.0
#         Else (feature 14 > 0.46934750000000003)
#          Predict: 1.0
#       Else (feature 26 > 0.0626088645)
#        If (feature 26 <= 0.14845986849999998)
#         Predict: 0.0
#        Else (feature 26 > 0.14845986849999998)
#         If (feature 15 <= 2.3618037139999997)
#          Predict: 1.0
#         Else (feature 15 > 2.3618037139999997)
#          Predict: 0.0
#     Else (feature 35 > 0.10804443799999999)
#      If (feature 20 <= 0.450272424)
#       If (feature 25 <= 0.2478796935)
#        If (feature 32 <= 154.5)
#         Predict: 0.0
#        Else (feature 32 > 154.5)
#         If (feature 31 <= 9418.0)
#          If (feature 19 <= 0.0320684215)
#           If (feature 15 <= 1.670659971)
#            Predict: 1.0
#           Else (feature 15 > 1.670659971)
#            Predict: 0.0
#          Else (feature 19 > 0.0320684215)
#           Predict: 1.0
#         Else (feature 31 > 9418.0)
#          Predict: 0.0
#       Else (feature 25 > 0.2478796935)
#        If (feature 27 <= 0.5)
#         Predict: 0.0
#        Else (feature 27 > 0.5)
#         Predict: 1.0
#      Else (feature 20 > 0.450272424)
#       If (feature 17 <= 0.2548584905)
#        If (feature 17 <= 0.002472188)
#         Predict: 0.0
#        Else (feature 17 > 0.002472188)
#         If (feature 14 <= 0.46934750000000003)
#          If (feature 27 <= 0.5)
#           Predict: 1.0
#          Else (feature 27 > 0.5)
#           If (feature 32 <= 203.5)
#            If (feature 17 <= 0.1790003365)
#             Predict: 0.0
#            Else (feature 17 > 0.1790003365)
#             Predict: 1.0
#           Else (feature 32 > 203.5)
#            Predict: 0.0
#         Else (feature 14 > 0.46934750000000003)
#          If (feature 23 <= 0.015001365999999999)
#           Predict: 0.0
#          Else (feature 23 > 0.015001365999999999)
#           If (feature 25 <= 0.30454012649999995)
#            If (feature 29 <= 6.5)
#             Predict: 1.0
#            Else (feature 29 > 6.5)
#             Predict: 1.0
#           Else (feature 25 > 0.30454012649999995)
#            Predict: 0.0
#       Else (feature 17 > 0.2548584905)
#        If (feature 23 <= 0.051887281)
#         If (feature 18 <= 0.1472803465)
#          If (feature 34 <= 0.4886039885)
#           Predict: 0.0
#          Else (feature 34 > 0.4886039885)
#           Predict: 1.0
#         Else (feature 18 > 0.1472803465)
#          If (feature 17 <= 0.2849050795)
#           Predict: 0.0
#          Else (feature 17 > 0.2849050795)
#           If (feature 32 <= 406.5)
#            Predict: 1.0
#           Else (feature 32 > 406.5)
#            Predict: 0.0
#        Else (feature 23 > 0.051887281)
#         If (feature 18 <= 0.2410261915)
#          Predict: 1.0
#         Else (feature 18 > 0.2410261915)
#          Predict: 0.0
#    Else (feature 1 not in {1.0})
#     If (feature 3 in {1.0})
#      If (feature 23 <= 0.0455830775)
#       If (feature 35 <= 0.13020503649999998)
#        If (feature 15 <= 2.75869631)
#         If (feature 34 <= 0.0183501685)
#          If (feature 33 <= 1.5)
#           If (feature 31 <= 7052.5)
#            Predict: 0.0
#           Else (feature 31 > 7052.5)
#            Predict: 1.0
#          Else (feature 33 > 1.5)
#           If (feature 26 <= 0.110140926)
#            Predict: 1.0
#           Else (feature 26 > 0.110140926)
#            Predict: 0.0
#         Else (feature 34 > 0.0183501685)
#          If (feature 29 <= 18.5)
#           If (feature 33 <= 7.5)
#            Predict: 1.0
#           Else (feature 33 > 7.5)
#            If (feature 17 <= 0.119859155)
#             Predict: 0.0
#            Else (feature 17 > 0.119859155)
#             Predict: 1.0
#          Else (feature 29 > 18.5)
#           If (feature 17 <= 0.08869223200000001)
#            If (feature 18 <= 0.0283353405)
#             Predict: 0.0
#            Else (feature 18 > 0.0283353405)
#             Predict: 1.0
#           Else (feature 17 > 0.08869223200000001)
#            If (feature 25 <= 0.2567133755)
#             Predict: 1.0
#            Else (feature 25 > 0.2567133755)
#             Predict: 1.0
#        Else (feature 15 > 2.75869631)
#         If (feature 25 <= 0.18307157200000002)
#          Predict: 0.0
#         Else (feature 25 > 0.18307157200000002)
#          If (feature 26 <= 0.020628228)
#           If (feature 17 <= 0.2849050795)
#            If (feature 33 <= 7.5)
#             Predict: 1.0
#            Else (feature 33 > 7.5)
#             Predict: 0.0
#           Else (feature 17 > 0.2849050795)
#            Predict: 0.0
#          Else (feature 26 > 0.020628228)
#           If (feature 33 <= 12.5)
#            If (feature 14 <= 0.3662915)
#             Predict: 1.0
#            Else (feature 14 > 0.3662915)
#             Predict: 1.0
#           Else (feature 33 > 12.5)
#            Predict: 0.0
#       Else (feature 35 > 0.13020503649999998)
#        If (feature 20 <= 0.4368365725)
#         Predict: 0.0
#        Else (feature 20 > 0.4368365725)
#         If (feature 34 <= 0.4886039885)
#          If (feature 16 <= 0.5582905465)
#           Predict: 1.0
#          Else (feature 16 > 0.5582905465)
#           If (feature 15 <= 2.3618037139999997)
#            Predict: 0.0
#           Else (feature 15 > 2.3618037139999997)
#            Predict: 1.0
#         Else (feature 34 > 0.4886039885)
#          Predict: 0.0
#      Else (feature 23 > 0.0455830775)
#       If (feature 19 <= 0.1114379085)
#        If (feature 18 <= 0.015564438)
#         If (feature 32 <= 121.5)
#          If (feature 25 <= 0.205348926)
#           Predict: 0.0
#          Else (feature 25 > 0.205348926)
#           If (feature 17 <= 0.002472188)
#            If (feature 23 <= 0.0594695065)
#             Predict: 1.0
#            Else (feature 23 > 0.0594695065)
#             Predict: 0.0
#           Else (feature 17 > 0.002472188)
#            If (feature 17 <= 0.4441734415)
#             Predict: 1.0
#            Else (feature 17 > 0.4441734415)
#             Predict: 0.0
#         Else (feature 32 > 121.5)
#          Predict: 0.0
#        Else (feature 18 > 0.015564438)
#         If (feature 26 <= 0.020628228)
#          If (feature 32 <= 154.5)
#           If (feature 20 <= 0.42028575700000004)
#            If (feature 15 <= 2.3618037139999997)
#             Predict: 0.0
#            Else (feature 15 > 2.3618037139999997)
#             Predict: 1.0
#           Else (feature 20 > 0.42028575700000004)
#            If (feature 23 <= 0.0594695065)
#             Predict: 0.0
#            Else (feature 23 > 0.0594695065)
#             Predict: 1.0
#          Else (feature 32 > 154.5)
#           If (feature 29 <= 21.5)
#            If (feature 16 <= 0.312213303)
#             Predict: 0.0
#            Else (feature 16 > 0.312213303)
#             Predict: 1.0
#           Else (feature 29 > 21.5)
#            Predict: 0.0
#         Else (feature 26 > 0.020628228)
#          If (feature 35 <= 0.167132216)
#           If (feature 15 <= 3.0912878790000002)
#            If (feature 23 <= 0.121407927)
#             Predict: 1.0
#            Else (feature 23 > 0.121407927)
#             Predict: 0.0
#           Else (feature 15 > 3.0912878790000002)
#            If (feature 26 <= 0.0626088645)
#             Predict: 1.0
#            Else (feature 26 > 0.0626088645)
#             Predict: 0.0
#          Else (feature 35 > 0.167132216)
#           Predict: 0.0
#       Else (feature 19 > 0.1114379085)
#        If (feature 32 <= 137.5)
#         If (feature 27 <= 0.5)
#          Predict: 0.0
#         Else (feature 27 > 0.5)
#          If (feature 34 <= 0.2188424555)
#           Predict: 1.0
#          Else (feature 34 > 0.2188424555)
#           Predict: 0.0
#        Else (feature 32 > 137.5)
#         If (feature 23 <= 0.0947221815)
#          Predict: 0.0
#         Else (feature 23 > 0.0947221815)
#          If (feature 14 <= 0.5427310000000001)
#           Predict: 0.0
#          Else (feature 14 > 0.5427310000000001)
#           Predict: 1.0
#     Else (feature 3 not in {1.0})
#      If (feature 14 <= 0.46934750000000003)
#       If (feature 15 <= 2.5314242565000002)
#        If (feature 18 <= 0.0878282675)
#         If (feature 29 <= 46.5)
#          If (feature 21 <= 3.285E-4)
#           If (feature 15 <= 2.2241901774999997)
#            If (feature 31 <= 2917.0)
#             Predict: 0.0
#            Else (feature 31 > 2917.0)
#             Predict: 1.0
#           Else (feature 15 > 2.2241901774999997)
#            If (feature 18 <= 0.0552377215)
#             Predict: 0.0
#            Else (feature 18 > 0.0552377215)
#             Predict: 1.0
#          Else (feature 21 > 3.285E-4)
#           If (feature 32 <= 243.5)
#            If (feature 29 <= 9.5)
#             Predict: 0.0
#            Else (feature 29 > 9.5)
#             Predict: 0.0
#           Else (feature 32 > 243.5)
#            Predict: 0.0
#         Else (feature 29 > 46.5)
#          If (feature 17 <= 0.2849050795)
#           If (feature 31 <= 4162.5)
#            Predict: 0.0
#           Else (feature 31 > 4162.5)
#            If (feature 0 in {0.0})
#             Predict: 0.0
#            Else (feature 0 not in {0.0})
#             Predict: 1.0
#          Else (feature 17 > 0.2849050795)
#           Predict: 1.0
#        Else (feature 18 > 0.0878282675)
#         If (feature 34 <= 0.0183501685)
#          If (feature 29 <= 33.5)
#           If (feature 26 <= 0.0099005965)
#            If (feature 19 <= 0.023143705)
#             Predict: 1.0
#            Else (feature 19 > 0.023143705)
#             Predict: 0.0
#           Else (feature 26 > 0.0099005965)
#            If (feature 20 <= 0.6113894185)
#             Predict: 1.0
#            Else (feature 20 > 0.6113894185)
#             Predict: 0.0
#          Else (feature 29 > 33.5)
#           If (feature 26 <= 0.110140926)
#            Predict: 0.0
#           Else (feature 26 > 0.110140926)
#            If (feature 25 <= 0.222973184)
#             Predict: 0.0
#            Else (feature 25 > 0.222973184)
#             Predict: 1.0
#         Else (feature 34 > 0.0183501685)
#          If (feature 26 <= 0.91704893)
#           If (feature 26 <= 0.0626088645)
#            If (feature 23 <= 0.0947221815)
#             Predict: 1.0
#            Else (feature 23 > 0.0947221815)
#             Predict: 0.0
#           Else (feature 26 > 0.0626088645)
#            If (feature 25 <= 0.18307157200000002)
#             Predict: 1.0
#            Else (feature 25 > 0.18307157200000002)
#             Predict: 1.0
#          Else (feature 26 > 0.91704893)
#           If (feature 33 <= 2.5)
#            Predict: 0.0
#           Else (feature 33 > 2.5)
#            If (feature 15 <= 1.962423665)
#             Predict: 0.0
#            Else (feature 15 > 1.962423665)
#             Predict: 1.0
#       Else (feature 15 > 2.5314242565000002)
#        If (feature 29 <= 21.5)
#         If (feature 23 <= 0.040342762)
#          If (feature 18 <= 0.1472803465)
#           If (feature 34 <= 0.143095238)
#            If (feature 23 <= 0.0353379105)
#             Predict: 0.0
#            Else (feature 23 > 0.0353379105)
#             Predict: 1.0
#           Else (feature 34 > 0.143095238)
#            If (feature 16 <= 0.6922237149999999)
#             Predict: 1.0
#            Else (feature 16 > 0.6922237149999999)
#             Predict: 0.0
#          Else (feature 18 > 0.1472803465)
#           If (feature 35 <= 0.13020503649999998)
#            If (feature 4 in {1.0})
#             Predict: 0.0
#            Else (feature 4 not in {1.0})
#             Predict: 1.0
#           Else (feature 35 > 0.13020503649999998)
#            If (feature 25 <= 0.23083599049999998)
#             Predict: 0.0
#            Else (feature 25 > 0.23083599049999998)
#             Predict: 1.0
#         Else (feature 23 > 0.040342762)
#          If (feature 19 <= 0.0320684215)
#           If (feature 18 <= 0.0414985725)
#            If (feature 25 <= 0.27862231400000004)
#             Predict: 1.0
#            Else (feature 25 > 0.27862231400000004)
#             Predict: 0.0
#           Else (feature 18 > 0.0414985725)
#            Predict: 1.0
#          Else (feature 19 > 0.0320684215)
#           If (feature 32 <= 137.5)
#            If (feature 35 <= 0.13020503649999998)
#             Predict: 0.0
#            Else (feature 35 > 0.13020503649999998)
#             Predict: 0.0
#           Else (feature 32 > 137.5)
#            Predict: 0.0
#        Else (feature 29 > 21.5)
#         If (feature 17 <= 0.3197633135)
#          If (feature 17 <= 0.1790003365)
#           Predict: 0.0
#          Else (feature 17 > 0.1790003365)
#           If (feature 18 <= 0.1472803465)
#            If (feature 16 <= 0.5982457485)
#             Predict: 0.0
#            Else (feature 16 > 0.5982457485)
#             Predict: 0.0
#           Else (feature 18 > 0.1472803465)
#            If (feature 23 <= 0.0263628375)
#             Predict: 0.0
#            Else (feature 23 > 0.0263628375)
#             Predict: 0.0
#         Else (feature 17 > 0.3197633135)
#          If (feature 33 <= 3.5)
#           If (feature 34 <= 0.0332329315)
#            If (feature 26 <= 0.0626088645)
#             Predict: 1.0
#            Else (feature 26 > 0.0626088645)
#             Predict: 0.0
#           Else (feature 34 > 0.0332329315)
#            Predict: 0.0
#          Else (feature 33 > 3.5)
#           If (feature 29 <= 65.5)
#            If (feature 25 <= 0.2659816935)
#             Predict: 0.0
#            Else (feature 25 > 0.2659816935)
#             Predict: 1.0
#           Else (feature 29 > 65.5)
#            Predict: 1.0
#      Else (feature 14 > 0.46934750000000003)
#       If (feature 5 in {1.0})
#        If (feature 26 <= 0.020628228)
#         If (feature 23 <= 0.0263628375)
#          Predict: 1.0
#         Else (feature 23 > 0.0263628375)
#          If (feature 18 <= 0.0878282675)
#           Predict: 0.0
#          Else (feature 18 > 0.0878282675)
#           If (feature 32 <= 137.5)
#            If (feature 17 <= 0.2039154315)
#             Predict: 0.0
#            Else (feature 17 > 0.2039154315)
#             Predict: 1.0
#           Else (feature 32 > 137.5)
#            If (feature 15 <= 2.2241901774999997)
#             Predict: 1.0
#            Else (feature 15 > 2.2241901774999997)
#             Predict: 0.0
#        Else (feature 26 > 0.020628228)
#         If (feature 35 <= 0.089318239)
#          If (feature 29 <= 6.5)
#           If (feature 14 <= 0.6075189999999999)
#            Predict: 0.0
#           Else (feature 14 > 0.6075189999999999)
#            Predict: 1.0
#          Else (feature 29 > 6.5)
#           If (feature 17 <= 0.3620421245)
#            Predict: 0.0
#           Else (feature 17 > 0.3620421245)
#            If (feature 20 <= 0.4993590195)
#             Predict: 0.0
#            Else (feature 20 > 0.4993590195)
#             Predict: 1.0
#         Else (feature 35 > 0.089318239)
#          If (feature 33 <= 7.5)
#           If (feature 18 <= 0.1229909755)
#            If (feature 15 <= 2.75869631)
#             Predict: 0.0
#            Else (feature 15 > 2.75869631)
#             Predict: 1.0
#           Else (feature 18 > 0.1229909755)
#            If (feature 14 <= 0.6075189999999999)
#             Predict: 0.0
#            Else (feature 14 > 0.6075189999999999)
#             Predict: 0.0
#          Else (feature 33 > 7.5)
#           Predict: 0.0
#       Else (feature 5 not in {1.0})
#        If (feature 29 <= 25.5)
#         If (feature 8 in {1.0})
#          If (feature 23 <= 0.021448402999999998)
#           If (feature 15 <= 2.3618037139999997)
#            If (feature 14 <= 0.8503704999999999)
#             Predict: 1.0
#            Else (feature 14 > 0.8503704999999999)
#             Predict: 0.0
#           Else (feature 15 > 2.3618037139999997)
#            Predict: 0.0
#          Else (feature 23 > 0.021448402999999998)
#           If (feature 32 <= 121.5)
#            If (feature 14 <= 0.5427310000000001)
#             Predict: 0.0
#            Else (feature 14 > 0.5427310000000001)
#             Predict: 0.0
#           Else (feature 32 > 121.5)
#            If (feature 20 <= 0.4740899715)
#             Predict: 0.0
#            Else (feature 20 > 0.4740899715)
#             Predict: 0.0
#         Else (feature 8 not in {1.0})
#          If (feature 20 <= 0.4993590195)
#           If (feature 33 <= 3.5)
#            If (feature 27 <= 0.5)
#             Predict: 0.0
#            Else (feature 27 > 0.5)
#             Predict: 1.0
#           Else (feature 33 > 3.5)
#            If (feature 35 <= 0.13020503649999998)
#             Predict: 1.0
#            Else (feature 35 > 0.13020503649999998)
#             Predict: 0.0
#          Else (feature 20 > 0.4993590195)
#           If (feature 26 <= 0.0099005965)
#            If (feature 14 <= 0.5427310000000001)
#             Predict: 0.0
#            Else (feature 14 > 0.5427310000000001)
#             Predict: 1.0
#           Else (feature 26 > 0.0099005965)
#            If (feature 34 <= 0.114543575)
#             Predict: 0.0
#            Else (feature 34 > 0.114543575)
#             Predict: 0.0
#        Else (feature 29 > 25.5)
#         If (feature 8 in {1.0})
#          If (feature 14 <= 0.6075189999999999)
#           If (feature 15 <= 2.75869631)
#            If (feature 35 <= 0.0952147295)
#             Predict: 1.0
#            Else (feature 35 > 0.0952147295)
#             Predict: 0.0
#           Else (feature 15 > 2.75869631)
#            Predict: 0.0
#          Else (feature 14 > 0.6075189999999999)
#           If (feature 32 <= 406.5)
#            Predict: 0.0
#           Else (feature 32 > 406.5)
#            If (feature 16 <= 0.6922237149999999)
#             Predict: 0.0
#            Else (feature 16 > 0.6922237149999999)
#             Predict: 1.0
#         Else (feature 8 not in {1.0})
#          If (feature 33 <= 10.5)
#           If (feature 20 <= 0.5192881229999999)
#            If (feature 15 <= 3.8598100229999996)
#             Predict: 0.0
#            Else (feature 15 > 3.8598100229999996)
#             Predict: 0.0
#           Else (feature 20 > 0.5192881229999999)
#            If (feature 14 <= 0.5427310000000001)
#             Predict: 1.0
#            Else (feature 14 > 0.5427310000000001)
#             Predict: 0.0
#          Else (feature 33 > 10.5)
#           If (feature 23 <= 0.0263628375)
#            If (feature 17 <= 0.2548584905)
#             Predict: 0.0
#            Else (feature 17 > 0.2548584905)
#             Predict: 1.0
#           Else (feature 23 > 0.0263628375)
#            If (feature 34 <= 0.0183501685)
#             Predict: 0.0
#            Else (feature 34 > 0.0183501685)
#             Predict: 0.0

# %% [markdown]
# # Predict the result with test set

# %%
predicted=pipelineModel.transform(test_df)

# %%
print(predicted.columns)
# Out:
# ['url', 'alchemy_category', 'alchemy_category_score', 'avglinksize', 'commonlinkratio_1', 'commonlinkratio_2', 'commonlinkratio_3', 'commonlinkratio_4', 'compression_ratio', 'embed_ratio', 'framebased', 'frameTagRatio', 'hasDomainLink', 'html_ratio', 'image_ratio', 'is_news', 'lengthyLinkDomain', 'linkwordscore', 'news_front_page', 'non_markup_alphanum_characters', 'numberOfLinks', 'numwords_in_url', 'parametrizedLinkRatio', 'spelling_errors_ratio', 'label', 'alchemy_category_Index', 'alchemy_category_IndexVec', 'features', 'rawPrediction', 'probability', 'prediction']

# %%
predicted.count()
# Out:
# 2243

# %%
predicted.select('url', 'features', 'rawprediction', 'probability', 'label', 'prediction').show(10)
# Out:
# +--------------------+--------------------+-------------+--------------------+-----+----------+
# |                 url|            features|rawprediction|         probability|label|prediction|
# +--------------------+--------------------+-------------+--------------------+-----+----------+
# |http://1000awesom...|(36,[0,15,16,17,1...| [15.0,128.0]|[0.10489510489510...|  1.0|       1.0|
# |http://1000awesom...|(36,[1,14,15,16,1...|    [0.0,8.0]|           [0.0,1.0]|  1.0|       1.0|
# |http://100miledie...|(36,[0,15,20,23,2...|    [0.0,9.0]|           [0.0,1.0]|  0.0|       1.0|
# |http://17andbakin...|(36,[3,14,15,16,1...|    [1.0,0.0]|           [1.0,0.0]|  1.0|       0.0|
# |http://17andbakin...|(36,[2,14,15,16,1...|[127.0,150.0]|[0.45848375451263...|  1.0|       1.0|
# |http://1x.com/pho...|(36,[0,15,16,17,2...|[127.0,204.0]|[0.38368580060422...|  1.0|       1.0|
# |http://2oddities....|(36,[8,14,15,16,1...|    [3.0,0.0]|           [1.0,0.0]|  1.0|       0.0|
# |http://3kidsandus...|(36,[0,15,16,17,1...| [15.0,128.0]|[0.10489510489510...|  0.0|       1.0|
# |http://98smile.co...|(36,[4,14,15,16,2...|   [48.0,1.0]|[0.97959183673469...|  1.0|       0.0|
# |http://98smile.co...|(36,[0,15,16,17,1...|   [11.0,3.0]|[0.78571428571428...|  0.0|       0.0|
# +--------------------+--------------------+-------------+--------------------+-----+----------+
# only showing top 10 rows

# %%
#probability=[probability of 0, probability of 1]
predicted.select('probability', 'label', 'prediction').take(10)
# Out:
# [Row(probability=DenseVector([0.1049, 0.8951]), label=1.0, prediction=1.0),
#  Row(probability=DenseVector([0.0, 1.0]), label=1.0, prediction=1.0),
#  Row(probability=DenseVector([0.0, 1.0]), label=0.0, prediction=1.0),
#  Row(probability=DenseVector([1.0, 0.0]), label=1.0, prediction=0.0),
#  Row(probability=DenseVector([0.4585, 0.5415]), label=1.0, prediction=1.0),
#  Row(probability=DenseVector([0.3837, 0.6163]), label=1.0, prediction=1.0),
#  Row(probability=DenseVector([1.0, 0.0]), label=1.0, prediction=0.0),
#  Row(probability=DenseVector([0.1049, 0.8951]), label=0.0, prediction=1.0),
#  Row(probability=DenseVector([0.9796, 0.0204]), label=1.0, prediction=0.0),
#  Row(probability=DenseVector([0.7857, 0.2143]), label=0.0, prediction=0.0)]

# %% [markdown]
# # Set up an evaluator

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator=BinaryClassificationEvaluator(
            rawPredictionCol = "rawPrediction",
            labelCol="label",
            metricName="areaUnderROC")

predictions=pipelineModel.transform(test_df)
auc = evaluator.evaluate(predictions)
auc
# Out:
# 0.6196074452508276
